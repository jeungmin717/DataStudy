# %%
import pandas as pd

# %%
df = pd.read_csv("apt_final.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429466 entries, 0 to 429465
# Data columns (total 62 columns):
# price_per_area          429466 non-null int64
# price                   429466 non-null float64
# con_year                429466 non-null int64
# year                    429466 non-null int64
# dong                    429466 non-null object
# aptnm                   429466 non-null object
# month                   429466 non-null int64
# dat                     429466 non-null object
# area                    429466 non-null float64
# area_sub                429466 non-null object
# loc                     429466 non-null int64
# floor                   429466 non-null int64
# qrt                     429466 non-null object
# yyyyqrt                 429466 non-null object
# yyyym                   429466 non-null int64
# gu                      429466 non-null object
# num_children            429466 non-null int64
# num_elementary          429466 non-null int64
# ...

# %%
df.columns
# Out:
# Index(['price_per_area', 'price', 'con_year', 'year', 'dong', 'aptnm', 'month',
#        'dat', 'area', 'area_sub', 'loc', 'floor', 'qrt', 'yyyyqrt', 'yyyym',
#        'gu', 'num_children', 'num_elementary', 'num_middle', 'num_high',
#        'edu_subsidy', 'basic_living', 'hospital', 'num_beds', 'park_area',
#        'salary_councilor', 'obesity', 'total_in', 'total_out', 'inner_in',
#        'inner_out', 'outer_in', 'outer_out', 'city_in', 'city_out',
#        'consm_price_idx', 'food_price_idx', 'prod_price_idx',
#        'rental_house_idx', 'pub_service_idx', 'pri_service_idx',
#        'source_price_idx', 'life_price_idx', 'debt', 'farm_assets',
#        'none_farm_assets', 'assets', 'current_assets', 'current_debt_ratio',
#        'asset_debt_ratio', 'seoul_cons_result', 'national_cons_result',
#        'seoul_cons_ratio', 'bond_one_year', 'bond_three_year',
#        'bond_five_year', 'bond_ten_year', 'corp_bond_yield_rate', 'call_rate',
# ...

# %%
df.head()
# Out:
#    price_per_area     price  con_year  year dong       aptnm  month   dat  \
# 0            1979   71000.0      1982  2009  개포동    개포주공 3단지     10  1~10
# 1            1994   83700.0      1982  2009  개포동    개포주공 1단지     10  1~10
# 2            1128  173500.0      2004  2009  개포동  개포자이(12-2)     10  1~10
# 3            1204   65000.0      1983  2009  개포동    개포주공 5단지     10  1~10
# 4            1214  160000.0      1986  2009  개포동         현대2     10  1~10
#
#      area area_sub  ...   seoul_cons_ratio  bond_one_year bond_three_year  \
# 0   35.87    small  ...          10.061728           3.52            4.47
# 1   41.98    small  ...          10.061728           3.52            4.47
# 2  153.80    large  ...          10.061728           3.52            4.47
# 3   53.98    small  ...          10.061728           3.52            4.47
# 4  131.83    large  ...          10.061728           3.52            4.47
#
# ...

# %%
df.columns
# Out:
# Index(['price_per_area', 'price', 'con_year', 'year', 'dong', 'aptnm', 'month',
#        'dat', 'area', 'area_sub', 'loc', 'floor', 'qrt', 'yyyyqrt', 'yyyym',
#        'gu', 'num_children', 'num_elementary', 'num_middle', 'num_high',
#        'edu_subsidy', 'basic_living', 'hospital', 'num_beds', 'park_area',
#        'salary_councilor', 'obesity', 'total_in', 'total_out', 'inner_in',
#        'inner_out', 'outer_in', 'outer_out', 'city_in', 'city_out',
#        'consm_price_idx', 'food_price_idx', 'prod_price_idx',
#        'rental_house_idx', 'pub_service_idx', 'pri_service_idx',
#        'source_price_idx', 'life_price_idx', 'debt', 'farm_assets',
#        'none_farm_assets', 'assets', 'current_assets', 'current_debt_ratio',
#        'asset_debt_ratio', 'seoul_cons_result', 'national_cons_result',
#        'seoul_cons_ratio', 'bond_one_year', 'bond_three_year',
#        'bond_five_year', 'bond_ten_year', 'corp_bond_yield_rate', 'call_rate',
# ...

# %%
dong_list = ["역삼동", "개포동", "청담동", "삼성동","대치동", "신사동", "논현동", "압구정동", "세곡동", "자곡동", "율현동", "일원동", "수서동", "도곡동", "논현1동", "논현2동", "삼성1동", "삼성2동", "대치1동", "대치2동", "대치4동", "역삼1동", "역삼2동", "도곡1동", "도곡2동", "개포1동", "개포2동", "개포4동", "일원본동", "일원1동", "일원2동"]

# %%
dong_list
# Out:
# ['역삼동',
#  '개포동',
#  '청담동',
#  '삼성동',
#  '대치동',
#  '신사동',
#  '논현동',
#  '압구정동',
#  '세곡동',
#  '자곡동',
#  '율현동',
#  '일원동',
#  '수서동',
#  '도곡동',
#  '논현1동',
#  '논현2동',
#  '삼성1동',
#  '삼성2동',
#  '대치1동',
#  '대치2동',
#  '대치4동',
#  '역삼1동',
#  '역삼2동',
#  '도곡1동',
#  '도곡2동',
#  '개포1동',
#  '개포2동',
#  '개포4동',
#  '일원본동',
#  '일원1동',
#  '일원2동']

# %%
df[df['dong'].isin(dong_list)]
# Out:
#         price_per_area     price  con_year  year dong           aptnm  month  \
# 0                 1979   71000.0      1982  2009  개포동        개포주공 3단지     10
# 1                 1994   83700.0      1982  2009  개포동        개포주공 1단지     10
# 2                 1128  173500.0      2004  2009  개포동      개포자이(12-2)     10
# 3                 1204   65000.0      1983  2009  개포동        개포주공 5단지     10
# 4                 1214  160000.0      1986  2009  개포동             현대2     10
# 5                 1480   75000.0      1982  2009  개포동        개포주공 4단지     10
# 6                 1030   82000.0      1987  2009  개포동             우성8     10
# 7                 1275   78000.0      1983  2009  개포동        개포주공 5단지     10
# 8                 1975  100000.0      1982  2009  개포동        개포주공 1단지     10
# 9                 1133   44800.0      1992  2009  개포동      성원대치2단지아파트     10
# 10                1115   37000.0      1992  2009  개포동      성원대치2단지아파트     10
# ...

# %%
df.dong.isin(dong_list)
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True
# 10         True
# 11         True
# 12         True
# 13         True
# 14         True
# 15         True
# 16         True
# 17         True
# 18         True
# 19         True
# 20         True
# 21         True
# 22         True
# 23         True
# 24         True
# 25         True
# 26         True
# 27         True
# 28         True
# 29         True
#           ...
# 429436    False
# 429437    False
# 429438    False
# 429439    False
# 429440    False
# 429441    False
# 429442    False
# 429443    False
# 429444    False
# 429445    False
# 429446    False
# 429447    False
# 429448    False
# 429449    False
# 429450    False
# 429451    False
# 429452    False
# 429453    False
# 429454    False
# 429455    False
# 429456    False
# 429457    False
# 429458    False
# 429459    False
# ...

# %%
#위에것이 필터하는 조건이다.

# %%
df[df.dong.isin(dong_list)]   #  df[  필터하는 조건 ]  #이건 데이터 테이블 .
# Out:
#         price_per_area     price  con_year  year dong           aptnm  month  \
# 0                 1979   71000.0      1982  2009  개포동        개포주공 3단지     10
# 1                 1994   83700.0      1982  2009  개포동        개포주공 1단지     10
# 2                 1128  173500.0      2004  2009  개포동      개포자이(12-2)     10
# 3                 1204   65000.0      1983  2009  개포동        개포주공 5단지     10
# 4                 1214  160000.0      1986  2009  개포동             현대2     10
# 5                 1480   75000.0      1982  2009  개포동        개포주공 4단지     10
# 6                 1030   82000.0      1987  2009  개포동             우성8     10
# 7                 1275   78000.0      1983  2009  개포동        개포주공 5단지     10
# 8                 1975  100000.0      1982  2009  개포동        개포주공 1단지     10
# 9                 1133   44800.0      1992  2009  개포동      성원대치2단지아파트     10
# 10                1115   37000.0      1992  2009  개포동      성원대치2단지아파트     10
# ...

# %%
df[df.dong.isin(dong_list)].price_per_area.mean()   # 평균
# Out:
# 1159.915258074253

# %%
#in 은 iterable .

[1,2,3] in [[1,2,3],4]    #[][] 두개써서 이터러블 만듬?
# Out:
# True

# %%
df.dong
# Out:
# 0         개포동
# 1         개포동
# 2         개포동
# 3         개포동
# 4         개포동
# 5         개포동
# 6         개포동
# 7         개포동
# 8         개포동
# 9         개포동
# 10        개포동
# 11        개포동
# 12        개포동
# 13        개포동
# 14        개포동
# 15        개포동
# 16        개포동
# 17        개포동
# 18        개포동
# 19        개포동
# 20        개포동
# 21        개포동
# 22        개포동
# 23        개포동
# 24        개포동
# 25        개포동
# 26        개포동
# 27        개포동
# 28        개포동
# 29        개포동
#          ...
# 429436    중화동
# 429437    중화동
# 429438    중화동
# 429439    중화동
# 429440    중화동
# 429441    중화동
# 429442    중화동
# 429443    중화동
# 429444    중화동
# 429445    중화동
# 429446    중화동
# 429447    중화동
# 429448    중화동
# 429449    중화동
# 429450    중화동
# 429451    중화동
# 429452    중화동
# 429453    중화동
# 429454    중화동
# 429455    중화동
# 429456    중화동
# 429457    중화동
# 429458    중화동
# 429459    중화동
# 429460    중화동
# 429461    중화동
# 429462    중화동
# 429463    중화동
# 429464    중화동
# 429465    중화동
# ...

# %%
df.dong in dong_list # 에러뜸
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-b08b3db31332> in <module>()
# ----> 1 df.dong in dong_list # 에러뜸
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1571         raise ValueError("The truth value of a {0} is ambiguous. "
#    1572                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1573                          .format(self.__class__.__name__))
#    1574
#    1575     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df.dong in(dong_list)  #결국 is in 은 함수형 패러다임으로 만듬.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-efa4aecd7361> in <module>()
# ----> 1 df.dong in(dong_list)  #결국 is in 은 함수형 패러다임으로 만듬.
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1571         raise ValueError("The truth value of a {0} is ambiguous. "
#    1572                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1573                          .format(self.__class__.__name__))
#    1574
#    1575     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
list(map(lambda x:x in dong_list ,df.dong))
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
# ...

# %%
#한개씩 나오기때문에 , 전체의 iterable 데이터를 하나씩 처리하려면 map 을 쓴다 , 저것이 isin 을 함수로 만들어논것이다 .

# %%
# is in 은 전체 칼럼중에서 있는냐없느냐 체크해주는 함수다 .

# %% [markdown]
# --------------------

# %%
#filter = df.isin({'State':['CA'],'Metro':['San Francisco']}) #in 다음에 dict 가 오면  key 만 체크함.  pandas(3) 에 내용추가.

# %%
# row : loc , iloc, data [ ]  : 조건에 맞는 행 뽑기.

# %% [markdown]
# 예시 df[df.State=='CA']

# %%
df2 =  df[["year","price"]]

# %%
df2.groupby(by="year").mean()
# Out:
#              price
# year
# 2009  53154.423087
# 2010  54481.975525
# 2011  47782.875191
# 2012  49748.876154
# 2013  47549.218954
# 2014  46254.399498
# 2015  47321.686795
# 2016  56794.748497
# 2017  65054.597161

# %%
df2.groupby(by="year") # 이런 object 는 덜 완전하다는것이다 . 음 뒤에 mean() 으로 하니까 나옴

# %%
#단순한 통계치 , 두번쨰는 합한 통계치 세번쨰는 아파트가격에 연도별 평균을 나타내는것 까지봄

# %% [markdown]
# # df2.plot.bar() 졸라느리다

# %% [markdown]
# %matplotlib inline

# %% [markdown]
# data2.plot.bar()
