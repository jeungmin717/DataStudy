# %% [markdown]
# ## pandas

# %% [markdown]
# 판다스는 전처리, 통계분석을 해준다.

# %% [markdown]
# 전처리와 통계치(그래프로 분석하는 것 포함)를 뽑아내는것(EDA)하는 데 쓰인다.

# %% [markdown]
# 먼저 데이터를 불러 들이는 것...
# 판다스는 R 의 기능을 많이 지원해준다

# %%
import pandas as pd #보통 pd 2글자로 줄여서 쓴다.

# %%
pd.__version__
# Out:
# '0.23.0'

# %%
# !python -m pip install --upgrade pip
# Out:
# ...
#   Found existing installation: pip 10.0.1
#     Uninstalling pip-10.0.1:
#       Successfully uninstalled pip-10.0.1
# ...

# %%
df = pd.read_csv('data-netflix.csv') #read계열은 data frame을 돌려준다.
df.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
type(df) #DataFrame 클래스 -> Pascal 방식으로 표현됨
# Out:
# pandas.core.frame.DataFrame

# %%
dir(df)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
df.info() # 데이터는 1000개짜리. column은 7개. 
# non-null -> 데이터 누락 X. 
# 데이터 타입은 크게 숫자형.문자형.

# 근데 ratingLevel은 941개, user rating score는 605개 있다. non-null인데 왜 1000개가 아니지?
# object는 string데이터를 나타낼 때가 많다.
# memory usage -> pandas는 모든 데이터를 메모리에 올려서 사용한다.
# 그래서 속도가 빠르다. 하지만 메모리보다 큰 범위를 해결할 수가 없다.
# dask는 디스크 기반으로 pandas처럼 할 수 있다. -> 그러나 디스크 기반이므로 속도가 느림.
# Excel에서 하는걸 거의 대부분 pandas에서 한다.
# 몇백만개는 우습게 할 것이다
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
# title                1000 non-null object
# rating               1000 non-null object
# ratingLevel          941 non-null object
# ratingDescription    1000 non-null int64
# release year         1000 non-null int64
# user rating score    605 non-null float64
# user rating size     1000 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 54.8+ KB

# %%
df.describe() # 기본적인 통계값을 준다. -> 우리 column이 7개 였는데 4개만 보여주네???
# --> 숫자형 데이터들을 보여준다!!!! R에서의 summary와 비슷함.
# Out:
#        ratingDescription  release year  user rating score  user rating size
# count         1000.00000   1000.000000         605.000000       1000.000000
# mean            67.36600   2010.335000          84.094215         80.783000
# std             30.78561      8.877927          12.344371          0.973066
# min             10.00000   1940.000000          55.000000         80.000000
# 25%             35.00000   2007.000000          75.000000         80.000000
# 50%             60.00000   2015.000000          88.000000         80.000000
# 75%             90.00000   2016.000000          95.000000         82.000000
# max            124.00000   2017.000000          99.000000         82.000000

# %% [markdown]
# 표준편차가 크다 : 의견이 다양하다,

# %% [markdown]
# info , describe

# %%
type(df.head())
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# df.head() 의 데이터 타입이 데이터프레임

# %%
df.head().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
# title                5 non-null object
# rating               5 non-null object
# ratingLevel          5 non-null object
# ratingDescription    5 non-null int64
# release year         5 non-null int64
# user rating score    4 non-null float64
# user rating size     5 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 360.0+ bytes

# %% [markdown]
# head 와 tail 은 큰 의미를 가진다
# 앞과 뒤의 분포가 다른걸 가질확률이 크다.

# %%
df.head().describe()
# Out:
#        ratingDescription  release year  user rating score  user rating size
# count           5.000000      5.000000           4.000000          5.000000
# mean           86.000000   2009.600000          93.000000         80.400000
# std            11.401754      5.176872           7.571878          0.894427
# min            70.000000   2004.000000          82.000000         80.000000
# 25%            80.000000   2006.000000          91.000000         80.000000
# 50%            90.000000   2008.000000          96.000000         80.000000
# 75%            90.000000   2014.000000          98.000000         80.000000
# max           100.000000   2016.000000          98.000000         82.000000

# %%
df.tail().describe()
# Out:
#        ratingDescription  release year  user rating score  user rating size
# count           5.000000      5.000000           2.000000               5.0
# mean           45.000000   2012.800000          88.500000              81.0
# std            13.693064      5.630275          12.020815               1.0
# min            35.000000   2003.000000          80.000000              80.0
# 25%            35.000000   2013.000000          84.250000              80.0
# 50%            35.000000   2016.000000          88.500000              81.0
# 75%            60.000000   2016.000000          92.750000              82.0
# max            60.000000   2016.000000          97.000000              82.0

# %% [markdown]
# mean 이  86 - > 45

# %% [markdown]
# 판다스는 ,통계와 전처리 부분

# %% [markdown]
# outlier detection 이상한거 찾기

# %% [markdown]
# ## 잘불러됬는가보고 , 전체 , 인포 ( 메모리값 ), 헤드 ,테일 ,샘플 본다  이 순서대로 간다
# 샘플은 랜덤하게 보는거

# %%
df.sample(10)
# Out:
#                               title rating  \
# 103               The Office (U.S.)  TV-14
# 139     Hot Girls Wanted: Turned On  TV-MA
# 335          Trouble with the Curve  PG-13
# 659                         Mulan 2      G
# 164       Unbreakable Kimmy Schmidt  TV-14
# 805  FernGully: The Last Rainforest      G
# 605                   Lilo & Stitch     PG
# 197              Only for One Night  TV-MA
# 694       Open Season: Scared Silly     PG
# 349                     Cheer Squad  TV-PG
#
#                                            ratingLevel  ratingDescription  \
# 103  Parents strongly cautioned. May be unsuitable ...                 90
# 139                                                NaN                110
# 335  Parents strongly cautioned. May be inappropria...                 80
# 659          General Audiences. Suitable for all ages.                 35
# 164  Parents strongly cautioned. May be unsuitable ...                 90
# ...

# %%
wdf = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',header=None)
#header 에 None 하면 , 컬럼명이 인덱스로됨

# %%
#web에 있는 데이터를 가져올 수 있다. UCI Iris data csv = , , , 쉼표로 나옴
#한달이면 툴은 배우는데 원리를 모른다, 통계라서

# %%
wdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# 0    150 non-null float64
# 1    150 non-null float64
# 2    150 non-null float64
# 3    150 non-null float64
# 4    150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
wdf.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
wdf.tail()
# Out:
#        0    1    2    3               4
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica

# %%
wdf.head().describe()
# Out:
#               0         1         2    3
# count  5.000000  5.000000  5.000000  5.0
# mean   4.860000  3.280000  1.400000  0.2
# std    0.207364  0.258844  0.070711  0.0
# min    4.600000  3.000000  1.300000  0.2
# 25%    4.700000  3.100000  1.400000  0.2
# 50%    4.900000  3.200000  1.400000  0.2
# 75%    5.000000  3.500000  1.400000  0.2
# max    5.100000  3.600000  1.500000  0.2

# %%
wdf.tail().describe()
# Out:
#             5.1       3.5       1.4       0.2
# count  5.000000  5.000000  5.000000  5.000000
# mean   6.320000  2.980000  5.180000  2.060000
# std    0.303315  0.319374  0.148324  0.230217
# min    5.900000  2.500000  5.000000  1.800000
# 25%    6.200000  3.000000  5.100000  1.900000
# 50%    6.300000  3.000000  5.200000  2.000000
# 75%    6.500000  3.000000  5.200000  2.300000
# max    6.700000  3.400000  5.400000  2.300000

# %%
wdf.describe()
# Out:
#               5.1         3.5         1.4         0.2
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %% [markdown]
# row 는 관측지 , column 은 변수 (구분되는것 ) - > 그래서 2차원의 형태로만든다.

# %% [markdown]
# 분석은 2차원데이터

# %% [markdown]
# 평균과 표준편차만 알면된다,
# 많은데이터는 대부분 정규분포를 이룬다.
#
# 평균에 밀집되면 표준편차가 작아진다
# 평균에 멀어지면 표준편차가커진다.
# 스쿠니스,
#
# 표준편차가 크고 작고,

# %% [markdown]
# 분석은 쪼개진것을 2차원의 형태로 만들어야한다.  나눠진 테이블을 묶어야함.
# DB에서는 붙어있는것을 쪼개어 나누었다, 그것의 반대이다.

# %%
wdf
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# 5    5.4  3.9  1.7  0.4     Iris-setosa
# 6    4.6  3.4  1.4  0.3     Iris-setosa
# 7    5.0  3.4  1.5  0.2     Iris-setosa
# 8    4.4  2.9  1.4  0.2     Iris-setosa
# 9    4.9  3.1  1.5  0.1     Iris-setosa
# 10   5.4  3.7  1.5  0.2     Iris-setosa
# 11   4.8  3.4  1.6  0.2     Iris-setosa
# 12   4.8  3.0  1.4  0.1     Iris-setosa
# 13   4.3  3.0  1.1  0.1     Iris-setosa
# 14   5.8  4.0  1.2  0.2     Iris-setosa
# 15   5.7  4.4  1.5  0.4     Iris-setosa
# 16   5.4  3.9  1.3  0.4     Iris-setosa
# 17   5.1  3.5  1.4  0.3     Iris-setosa
# 18   5.7  3.8  1.7  0.3     Iris-setosa
# 19   5.1  3.8  1.5  0.3     Iris-setosa
# 20   5.4  3.4  1.7  0.2     Iris-setosa
# 21   5.1  3.7  1.5  0.4     Iris-setosa
# ...

# %% [markdown]
# 데이터 새로 한줄은 시리즈 , 왼쪽 번호는 인덱스 , 위에 컬럼명, 혹은  인덱스,

# %% [markdown]
# (리스트, 튜플 , 이런것들은 ) dataframe 도 시퀀스는 인덱싱과 슬라이싱이 된다.

# %%
df = pd.read_csv('data-netflix.csv',header=2)
df
# Out:
#                             Lucky Number Slevin      R  \
# 0                                Grey's Anatomy  TV-14
# 1                                  Prison Break  TV-14
# 2                         How I Met Your Mother  TV-PG
# 3                                  Supernatural  TV-14
# 4                                  Breaking Bad  TV-MA
# 5                           The Vampire Diaries  TV-14
# 6                              The Walking Dead  TV-MA
# 7                           Pretty Little Liars  TV-14
# 8                              Once Upon a Time  TV-PG
# 9                                      Sherlock  TV-14
# 10                                   Death Note  TV-14
# 11                                       Naruto  TV-PG
# 12                                   The Hunter      R
# 13                        Lottie Dottie Chicken   TV-Y
# 14                                        Arrow  TV-14
# 15                                 Black Mirror  TV-MA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998 entries, 0 to 997
# Data columns (total 7 columns):
# Lucky Number Slevin                                   998 non-null object
# R                                                     998 non-null object
# strong violence, sexual content and adult language    939 non-null object
# 100                                                   998 non-null int64
# 2006                                                  998 non-null int64
# NA                                                    604 non-null float64
# 82                                                    998 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 54.7+ KB

# %% [markdown]
# header 2를 하니까 데이터를 날려버림

# %%
#인덱스 컬럼을 잡아줄 수 있다. 인덱스는 해쉬와 같다. 

df = pd.read_csv('data-netflix.csv',usecols = ['title','rating','release year'])
df
# Out:
#                                           title rating  release year
# 0                                  White Chicks  PG-13          2004
# 1                           Lucky Number Slevin      R          2006
# 2                                Grey's Anatomy  TV-14          2016
# 3                                  Prison Break  TV-14          2008
# 4                         How I Met Your Mother  TV-PG          2014
# 5                                  Supernatural  TV-14          2016
# 6                                  Breaking Bad  TV-MA          2013
# 7                           The Vampire Diaries  TV-14          2017
# 8                              The Walking Dead  TV-MA          2015
# 9                           Pretty Little Liars  TV-14          2016
# 10                             Once Upon a Time  TV-PG          2016
# 11                                     Sherlock  TV-14          2016
# 12                                   Death Note  TV-14          2006
# ...

# %% [markdown]
# 보통 여러개 넣을때는 리스트로 넣는다,
# 한개넣을때는 스트링으로 넣는다.
# list 특징 :  <뮤터블 시퀀스 컨테이너>
#
# 똑똑한사람들은 처음부터 몇몇 컬럼이 필요없다고 뺀다 . 메모리에 다 올리는거라서

# %% [markdown]
# Ad hoc  : 특정문제는 특정 답만있다, 일반해는없다  no free lunch 공짜밥은없다 , 어떠한것을 하기위해서는 어떤노력을해야한다, 돌려말하면 일반적인 해답이 없다. 모든 경우에 맞는 답은없다

# %%
df = pd.read_csv('data-netflix.csv',na_values=[""])  # 널값을 지정해줄수있다.

# %%
df =pd.read_csv('data-netflix.csv',skip_blank_lines=False)

# %% [markdown]
# ## Skip rows

# %%
df.tail(2)
# Out:
#                title rating  release year
# 998      Beary Tales   TV-G          2013
# 999  Growing Up Wild      G          2016

# %%
df =pd.read_csv('data-netflix.csv',skipfooter=2,engine='python')  #뭐 안된다 깨진다, 인코딩에러 시 engine 에 파이썬 쓴다.

# %%
df.tail(2)
# Out:
#                        title rating                     ratingLevel  \
# 996  The Secret Life of Pets     PG  for action and some rude humor
# 997         Precious Puppies   TV-G          Suitable for all ages.
#
#      ratingDescription  release year  user rating score  user rating size
# 996                 60          2016                NaN                81
# 997                 35          2003                NaN                82

# %% [markdown]
# C 에 비해서 파이썬은 5배에서 100 배 가 느리다. 깨질때 engine (Unicode) 또는 encoding 쓴다.

# %%
import seaborn as sns #판다스 기반의 visualize

# %%
data = sns.load_dataset('tips',engine="python")

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df =pd.read_csv('data-netflix.csv',nrows=100)

# %%
df
# Out:
#                               title rating  \
# 0                      White Chicks  PG-13
# 1               Lucky Number Slevin      R
# 2                    Grey's Anatomy  TV-14
# 3                      Prison Break  TV-14
# 4             How I Met Your Mother  TV-PG
# 5                      Supernatural  TV-14
# 6                      Breaking Bad  TV-MA
# 7               The Vampire Diaries  TV-14
# 8                  The Walking Dead  TV-MA
# 9               Pretty Little Liars  TV-14
# 10                 Once Upon a Time  TV-PG
# 11                         Sherlock  TV-14
# 12                       Death Note  TV-14
# 13                           Naruto  TV-PG
# 14                       The Hunter      R
# 15            Lottie Dottie Chicken   TV-Y
# 16                            Arrow  TV-14
# 17                     Black Mirror  TV-MA
# 18                    The Originals  TV-14
# 19                          The 100     NR
# 20               Masha and the Bear   TV-Y
# ...

# %%
df.shape
# Out:
# (100, 7)

# %%
# numpy 에서 shape 봄. pandas 도 numpy 기반, 파이썬은 C 보다 5-100배느린게 정설이다 . 
# numpy가 C 기반이다 . 따라서 매우 빠르다 ,

# %% [markdown]
# 위의 shape 은 100줄 , 컬럼 7개

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
# title                100 non-null object
# rating               100 non-null object
# ratingLevel          83 non-null object
# ratingDescription    100 non-null int64
# release year         100 non-null int64
# user rating score    75 non-null float64
# user rating size     100 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 5.5+ KB

# %%
#우리는 2차원데이터로 통일을 해야 분석을 할 수 있다.

# %%
movies_json = pd.read_json('data-netflix.json')

# %%
movies_json
# Out:
#                                           title rating  \
# 0                                  White Chicks  PG-13
# 1                           Lucky Number Slevin      R
# 10                             Once Upon a Time  TV-PG
# 100          The Life Aquatic with Steve Zissou      R
# 101                         Lucky Number Slevin      R
# 102                                  The L Word  TV-MA
# 103                           The Office (U.S.)  TV-14
# 104                                     30 Rock  TV-14
# 105                                     Mad Men  TV-14
# 106           It's Always Sunny in Philadelphia  TV-MA
# 107                             Californication  TV-MA
# 108                        Parks and Recreation  TV-14
# 109                                     Friends  TV-14
# 11                                     Sherlock  TV-14
# 110                            Shameless (U.S.)  TV-MA
# 111                                  Portlandia  TV-14
# ...

# %%
df = pd.read_pickle('data-netflix.p')

# %%
df.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %% [markdown]
# pickle 은 파이썬에서 객체를 저장하는것,직렬화 방식 ,중간저장할대 pickle 많이씀.  확장자 마음데로가능.

# %%
import sqlite3

# %%
conn= sqlite3.connect('data-netflix.sqlite')

# %%
df = pd.read_sql_query("SELECT * FROM data_netflix;",conn)

# %%
df.head()
# Out:
#    ogc_fid                  title rating  \
# 0        1           White Chicks  PG-13
# 1        2    Lucky Number Slevin      R
# 2        3         Grey's Anatomy  TV-14
# 3        4           Prison Break  TV-14
# 4        5  How I Met Your Mother  TV-PG
#
#                                          ratinglevel ratingdescription  \
# 0  crude and sexual humor, language and some drug...                80
# 1  strong violence, sexual content and adult lang...               100
# 2  Parents strongly cautioned. May be unsuitable ...                90
# 3  Parents strongly cautioned. May be unsuitable ...                90
# 4  Parental guidance suggested. May not be suitab...                70
#
#   release year user rating score user rating size
# 0         2004                82               80
# 1         2006                NA               82
# 2         2016                98               80
# 3         2008                98               80
# ...

# %% [markdown]
# sql 안쓰고 바로 orm 으로 바꾸는게 가능하다 .

# %% [markdown]
# 객체만들고 ,인스턴스 방법. 클래스 메소드중 from 방법,

# %%
df = pd.read_csv('data-netflix.csv',encoding="utf-8")
df.to_html('ddd.html')
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-148-7733025020f1> in <module>()
#       1 df = pd.read_csv('data-netflix.csv',encoding="utf-8")
# ----> 2 df.to_html('ddd.html')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_html(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, bold_rows, classes, escape, max_rows, max_cols, show_dimensions, notebook, decimal, border, table_id)
#    2032                                            decimal=decimal, table_id=table_id)
#    2033         # TODO: a generic formatter wld b in DataFrameFormatter
# -> 2034         formatter.to_html(classes=classes, notebook=notebook, border=border)
#    2035
#    2036         if buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in to_html(self, classes, notebook, border)
# ...

# %%
df[["title","rating"]] #판다스는 여러개있으면 list 로 쓴다, 열을 가져올때는 이름을 쓴다
# Out:
#                                           title rating
# 0                                  White Chicks  PG-13
# 1                           Lucky Number Slevin      R
# 2                                Grey's Anatomy  TV-14
# 3                                  Prison Break  TV-14
# 4                         How I Met Your Mother  TV-PG
# 5                                  Supernatural  TV-14
# 6                                  Breaking Bad  TV-MA
# 7                           The Vampire Diaries  TV-14
# 8                              The Walking Dead  TV-MA
# 9                           Pretty Little Liars  TV-14
# 10                             Once Upon a Time  TV-PG
# 11                                     Sherlock  TV-14
# 12                                   Death Note  TV-14
# 13                                       Naruto  TV-PG
# 14                                   The Hunter      R
# 15                        Lottie Dottie Chicken   TV-Y
# ...

# %%
df['title']  # 꺽쇄 하나는 시리즈 객체를 들고온다 .
# Out:
# 0                                    White Chicks
# 1                             Lucky Number Slevin
# 2                                  Grey's Anatomy
# 3                                    Prison Break
# 4                           How I Met Your Mother
# 5                                    Supernatural
# 6                                    Breaking Bad
# 7                             The Vampire Diaries
# 8                                The Walking Dead
# 9                             Pretty Little Liars
# 10                               Once Upon a Time
# 11                                       Sherlock
# 12                                     Death Note
# 13                                         Naruto
# 14                                     The Hunter
# 15                          Lottie Dottie Chicken
# 16                                          Arrow
# 17                                   Black Mirror
# 18                                  The Originals
# ...

# %%
type(df['title'])
# Out:
# pandas.core.series.Series

# %%
df[['title']]  # 꺽쇄를 두개하면 데이터 프레임이됨.
# Out:
#                                           title
# 0                                  White Chicks
# 1                           Lucky Number Slevin
# 2                                Grey's Anatomy
# 3                                  Prison Break
# 4                         How I Met Your Mother
# 5                                  Supernatural
# 6                                  Breaking Bad
# 7                           The Vampire Diaries
# 8                              The Walking Dead
# 9                           Pretty Little Liars
# 10                             Once Upon a Time
# 11                                     Sherlock
# 12                                   Death Note
# 13                                       Naruto
# 14                                   The Hunter
# 15                        Lottie Dottie Chicken
# 16                                        Arrow
# 17                                 Black Mirror
# 18                                The Originals
# ...

# %%
type(df[['title']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ---

# %%
df = pd.read_json('data-netflix.json')

# %%
df = str(df)

# %%
df   =  df.encode('utf-8').decode('utf-8')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-163-2b8f3f2d4988> in <module>()
# ----> 1 df = dataframe(df)
#
# NameError: name 'dataframe' is not defined

# %%
df.to_html('a.html')
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-154-76755bba991d> in <module>()
# ----> 1 type(df.to_html('a.html'))
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_html(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, bold_rows, classes, escape, max_rows, max_cols, show_dimensions, notebook, decimal, border, table_id)
#    2032                                            decimal=decimal, table_id=table_id)
#    2033         # TODO: a generic formatter wld b in DataFrameFormatter
# -> 2034         formatter.to_html(classes=classes, notebook=notebook, border=border)
#    2035
#    2036         if buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in to_html(self, classes, notebook, border)
#     752         elif isinstance(self.buf, compat.string_types):
# ...
