# %% [markdown]
# 판다스 는 분석하기 좋은 데이터 set 으로 변환하는거.  관계형 데이터 셋으로 불러들어올수있고,
# 몽고디비로 불러들일수있다. 2차원데이터 즉 raw 와 column형태로 불러들인다.
#
# 수집할때부터 잘만들어놓으면 편하다 .
#
# 저장과 분석은 다르다, 저장은 여러 테이블로 나눠서 저장
# 분석은 하나의 테이블로 만들어서 저장,
# 관계형데이터베이스 데이터프레임.
#
#
# 판다스는 데이터프레임으로 2차원데이터형태를 나타냄
# 구성:헤더:컬럼네임, 인덱스, 한열은 시리즈라는 애, 데이터프레임.

# %%
import pandas as pd

# %%
df = pd.read_csv('data-zillow.csv')   #불러들일때 잘못 불러지면 ,  sep = ',' 를 붙여 줘야함. 엔진이 조금씩 달라서 똑바로 안읽어지면 구분자를 주어야한다

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10830 entries, 0 to 10829
# Data columns (total 8 columns):
# Date          10830 non-null object
# RegionID      10830 non-null int64
# RegionName    10830 non-null object
# State         10830 non-null object
# Metro         10256 non-null object
# County        10830 non-null object
# SizeRank      10830 non-null int64
# Zhvi          10830 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 677.0+ KB

# %%
df.describe()
# Out:
#             RegionID      SizeRank          Zhvi
# count   10830.000000  10830.000000  1.083000e+04
# mean    84344.818837   5414.500000  2.503076e+05
# std    125679.686534   3126.496042  2.565582e+05
# min      3301.000000      0.000000  3.740000e+04
# 25%     19346.250000   2707.250000  1.269000e+05
# 50%     35444.500000   5414.500000  1.818000e+05
# 75%     52608.250000   8121.750000  2.823500e+05
# max    737791.000000  10829.000000  6.343800e+06

# %%
df.head()
# Out:
#          Date  RegionID    RegionName State                           Metro  \
# 0  2017-05-31      6181      New York    NY                        New York
# 1  2017-05-31     12447   Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 2  2017-05-31     17426       Chicago    IL                         Chicago
# 3  2017-05-31     13271  Philadelphia    PA                    Philadelphia
# 4  2017-05-31     40326       Phoenix    AZ                         Phoenix
#
#          County  SizeRank    Zhvi
# 0        Queens         0  672400
# 1   Los Angeles         1  629900
# 2          Cook         2  222700
# 3  Philadelphia         3  137300
# 4      Maricopa         4  211300

# %%
df.tail()
# Out:
#              Date  RegionID         RegionName State     Metro      County  \
# 10825  2017-05-31     26077            Nehalem    OR       NaN   Tillamook
# 10826  2017-05-31     24105  Clear Lake Shores    TX   Houston   Galveston
# 10827  2017-05-31    737788    Lebanon Borough    NJ  New York   Hunterdon
# 10828  2017-05-31    182023            Henrico    VA  Richmond     Henrico
# 10829  2017-05-31     51793     East Hampstead    NH    Boston  Rockingham
#
#        SizeRank    Zhvi
# 10825     10825  392200
# 10826     10826  191900
# 10827     10827  231100
# 10828     10828  230800
# 10829     10829  296400

# %%
df.sample(5)
# Out:
#             Date  RegionID RegionName State        Metro   County  SizeRank  \
# 9026  2017-05-31     30857    Chester    MA  Springfield  Hampden      9026
# 2752  2017-05-31     32735     Mastic    NY     New York  Suffolk      2752
# 7302  2017-05-31     15992  Wind Lake    WI       Racine   Racine      7302
# 6628  2017-05-31     42194     Gaines    MI        Flint  Genesee      6628
# 1961  2017-05-31     26624   Prichard    AL       Mobile   Mobile      1961
#
#         Zhvi
# 9026  172200
# 2752  211000
# 7302  250900
# 6628  159100
# 1961   48100

# %%
df.columns
# Out:
# Index(['Date', 'RegionID', 'RegionName', 'State', 'Metro', 'County',
#        'SizeRank', 'Zhvi'],
#       dtype='object')

# %%
df.loc[:,"RegionName"]
# Out:
# 0                 New York
# 1              Los Angeles
# 2                  Chicago
# 3             Philadelphia
# 4                  Phoenix
# 5                Las Vegas
# 6                San Diego
# 7                   Dallas
# 8                 San Jose
# 9             Jacksonville
# 10           San Francisco
# 11                  Austin
# 12                 Detroit
# 13                Columbus
# 14                 Memphis
# 15               Charlotte
# 16                 El Paso
# 17                  Boston
# 18                 Seattle
# 19               Baltimore
# 20                  Denver
# 21              Washington
# 22               Nashville
# 23               Milwaukee
# 24                  Tucson
# 25                Portland
# 26           Oklahoma City
# 27                   Omaha
# 28             Albuquerque
# 29                  Fresno
#                ...
# 10800         Mount Sidney
# 10801          Cedar Grove
# 10802                Clark
# ...

# %%
df.RegionName
# Out:
# 0                 New York
# 1              Los Angeles
# 2                  Chicago
# 3             Philadelphia
# 4                  Phoenix
# 5                Las Vegas
# 6                San Diego
# 7                   Dallas
# 8                 San Jose
# 9             Jacksonville
# 10           San Francisco
# 11                  Austin
# 12                 Detroit
# 13                Columbus
# 14                 Memphis
# 15               Charlotte
# 16                 El Paso
# 17                  Boston
# 18                 Seattle
# 19               Baltimore
# 20                  Denver
# 21              Washington
# 22               Nashville
# 23               Milwaukee
# 24                  Tucson
# 25                Portland
# 26           Oklahoma City
# 27                   Omaha
# 28             Albuquerque
# 29                  Fresno
#                ...
# 10800         Mount Sidney
# 10801          Cedar Grove
# 10802                Clark
# ...

# %%
df["RegionName"]
# Out:
# 0                 New York
# 1              Los Angeles
# 2                  Chicago
# 3             Philadelphia
# 4                  Phoenix
# 5                Las Vegas
# 6                San Diego
# 7                   Dallas
# 8                 San Jose
# 9             Jacksonville
# 10           San Francisco
# 11                  Austin
# 12                 Detroit
# 13                Columbus
# 14                 Memphis
# 15               Charlotte
# 16                 El Paso
# 17                  Boston
# 18                 Seattle
# 19               Baltimore
# 20                  Denver
# 21              Washington
# 22               Nashville
# 23               Milwaukee
# 24                  Tucson
# 25                Portland
# 26           Oklahoma City
# 27                   Omaha
# 28             Albuquerque
# 29                  Fresno
#                ...
# 10800         Mount Sidney
# 10801          Cedar Grove
# 10802                Clark
# ...

# %%
df.iloc[:,2]      #  , 앞에는 행이다 .
# Out:
# 0                 New York
# 1              Los Angeles
# 2                  Chicago
# 3             Philadelphia
# 4                  Phoenix
# 5                Las Vegas
# 6                San Diego
# 7                   Dallas
# 8                 San Jose
# 9             Jacksonville
# 10           San Francisco
# 11                  Austin
# 12                 Detroit
# 13                Columbus
# 14                 Memphis
# 15               Charlotte
# 16                 El Paso
# 17                  Boston
# 18                 Seattle
# 19               Baltimore
# 20                  Denver
# 21              Washington
# 22               Nashville
# 23               Milwaukee
# 24                  Tucson
# 25                Portland
# 26           Oklahoma City
# 27                   Omaha
# 28             Albuquerque
# 29                  Fresno
#                ...
# 10800         Mount Sidney
# 10801          Cedar Grove
# 10802                Clark
# ...

# %%
# 4가지모두 색상이 없으니까 series 형식이다 .

# %%
df.count()
# Out:
# Date          10830
# RegionID      10830
# RegionName    10830
# State         10830
# Metro         10256
# County        10830
# SizeRank      10830
# Zhvi          10830
# dtype: int64

# %%
df.kurtosis()
# Out:
# RegionID     2.291461
# SizeRank    -1.200000
# Zhvi        82.042387
# dtype: float64

# %%
df.skew()
# Out:
# RegionID    1.973159
# SizeRank    0.000000
# Zhvi        6.714811
# dtype: float64

# %%
df.corr()
# Out:
#           RegionID  SizeRank      Zhvi
# RegionID  1.000000  0.052025 -0.032184
# SizeRank  0.052025  1.000000 -0.115621
# Zhvi     -0.032184 -0.115621  1.000000

# %%
df.cov()
# Out:
#               RegionID      SizeRank          Zhvi
# RegionID  1.579538e+10  2.044245e+07 -1.037760e+09
# SizeRank  2.044245e+07  9.774978e+06 -9.274275e+07
# Zhvi     -1.037760e+09 -9.274275e+07  6.582212e+10

# %%
#상관변수이런건안알려준다 , 상관계수 통계공부하라고

# %%
#예전에 R 을 rpy2 로 연결해서 썼었다 , 느렸음 90퍼의 R 기능들을 python 에서 쓸 수 있었다.
#파이썬을 더많이쓰는이유가 딥러닝때문에 , R에도 딥러닝 패키지있는데 10퍼센트도안됨성능이
#딥러닝도 할 수 있어야하고 , r 도 해야하고 파이썬도 해야하고 ,

# %%
df.corr()
# Out:
#           RegionID  SizeRank      Zhvi
# RegionID  1.000000  0.052025 -0.032184
# SizeRank  0.052025  1.000000 -0.115621
# Zhvi     -0.032184 -0.115621  1.000000

# %%
#변수 두개 끼리의 관계,  corr ,

# %% [markdown]
#  ## 공분산 상관계수가 뭔지 공부하기 .

# %%
df.iloc[:,1:3]   #iloc 는 맨끝의 인덱스 포함안하니까 콜럼 2개나옴 3개아님
# Out:
#        RegionID         RegionName
# 0          6181           New York
# 1         12447        Los Angeles
# 2         17426            Chicago
# 3         13271       Philadelphia
# 4         40326            Phoenix
# 5         18959          Las Vegas
# 6         54296          San Diego
# 7         38128             Dallas
# 8         33839           San Jose
# 9         25290       Jacksonville
# 10        20330      San Francisco
# 11        10221             Austin
# 12        17762            Detroit
# 13        10920           Columbus
# 14        32811            Memphis
# 15        24043          Charlotte
# 16        17933            El Paso
# 17        44269             Boston
# 18        16037            Seattle
# 19         3523          Baltimore
# 20        11093             Denver
# 21        41568         Washington
# 22         6118          Nashville
# 23         5976          Milwaukee
# 24         7481             Tucson
# 25        13373           Portland
# ...

# %%
df.at[1,"Metro"] = df.at[1,"Metro"].replace("-"," ",1)

# %%
df
# Out:
#              Date  RegionID         RegionName State  \
# 0      2017-05-31      6181           New York    NY
# 1      2017-05-31     12447        Los Angeles    CA
# 2      2017-05-31     17426            Chicago    IL
# 3      2017-05-31     13271       Philadelphia    PA
# 4      2017-05-31     40326            Phoenix    AZ
# 5      2017-05-31     18959          Las Vegas    NV
# 6      2017-05-31     54296          San Diego    CA
# 7      2017-05-31     38128             Dallas    TX
# 8      2017-05-31     33839           San Jose    CA
# 9      2017-05-31     25290       Jacksonville    FL
# 10     2017-05-31     20330      San Francisco    CA
# 11     2017-05-31     10221             Austin    TX
# 12     2017-05-31     17762            Detroit    MI
# 13     2017-05-31     10920           Columbus    OH
# 14     2017-05-31     32811            Memphis    TN
# 15     2017-05-31     24043          Charlotte    NC
# 16     2017-05-31     17933            El Paso    TX
# ...

# %%
df.loc[1:7,'Metro':'County']
# Out:
#                             Metro        County
# 1  Los Angeles Long Beach-Anaheim   Los Angeles
# 2                         Chicago          Cook
# 3                    Philadelphia  Philadelphia
# 4                         Phoenix      Maricopa
# 5                       Las Vegas         Clark
# 6                       San Diego     San Diego
# 7               Dallas-Fort Worth        Dallas

# %%
df["새로운열"]  =  3

# %%
df
# Out:
#              Date  RegionID         RegionName State  \
# 0      2017-05-31      6181           New York    NY
# 1      2017-05-31     12447        Los Angeles    CA
# 2      2017-05-31     17426            Chicago    IL
# 3      2017-05-31     13271       Philadelphia    PA
# 4      2017-05-31     40326            Phoenix    AZ
# 5      2017-05-31     18959          Las Vegas    NV
# 6      2017-05-31     54296          San Diego    CA
# 7      2017-05-31     38128             Dallas    TX
# 8      2017-05-31     33839           San Jose    CA
# 9      2017-05-31     25290       Jacksonville    FL
# 10     2017-05-31     20330      San Francisco    CA
# 11     2017-05-31     10221             Austin    TX
# 12     2017-05-31     17762            Detroit    MI
# 13     2017-05-31     10920           Columbus    OH
# 14     2017-05-31     32811            Memphis    TN
# 15     2017-05-31     24043          Charlotte    NC
# 16     2017-05-31     17933            El Paso    TX
# ...

# %%
del df['새로운열']

# %%
df
# Out:
#              Date  RegionID         RegionName State  \
# 0      2017-05-31      6181           New York    NY
# 1      2017-05-31     12447        Los Angeles    CA
# 2      2017-05-31     17426            Chicago    IL
# 3      2017-05-31     13271       Philadelphia    PA
# 4      2017-05-31     40326            Phoenix    AZ
# 5      2017-05-31     18959          Las Vegas    NV
# 6      2017-05-31     54296          San Diego    CA
# 7      2017-05-31     38128             Dallas    TX
# 8      2017-05-31     33839           San Jose    CA
# 9      2017-05-31     25290       Jacksonville    FL
# 10     2017-05-31     20330      San Francisco    CA
# 11     2017-05-31     10221             Austin    TX
# 12     2017-05-31     17762            Detroit    MI
# 13     2017-05-31     10920           Columbus    OH
# 14     2017-05-31     32811            Memphis    TN
# 15     2017-05-31     24043          Charlotte    NC
# 16     2017-05-31     17933            El Paso    TX
# ...

# %%
# 추가 삭제는 파이썬 처럼 가능.

# %%
df.iloc[1,4]
# Out:
# 'Los Angeles Long Beach-Anaheim'

# %%
df.iloc[[7,9],3:5]
# Out:
#   State              Metro
# 7    TX  Dallas-Fort Worth
# 9    FL       Jacksonville

# %%
df.loc[201:204,"State":"County"]
# Out:
#     State                           Metro         County
# 201    OH                          Canton          Stark
# 202    LA                     New Orleans      Jefferson
# 203    CA       Santa Maria-Santa Barbara  Santa Barbara
# 204    CA  Los Angeles-Long Beach-Anaheim    Los Angeles

# %%
df.loc[201:204,["State","County"]]
# Out:
#     State         County
# 201    OH          Stark
# 202    LA      Jefferson
# 203    CA  Santa Barbara
# 204    CA    Los Angeles

# %%
# iloc는 뒤에꺼 포함안된다 loc 는 뒤에꺼 포함된다.
#202째부터 205까지 , 4번째부터 6번째까지. 
df.iloc[201:205,3:6]
# Out:
#     State                           Metro         County
# 201    OH                          Canton          Stark
# 202    LA                     New Orleans      Jefferson
# 203    CA       Santa Maria-Santa Barbara  Santa Barbara
# 204    CA  Los Angeles-Long Beach-Anaheim    Los Angeles

# %%
df.loc[df.County=="Queens"]  #조건부 서식
# Out:
#          Date  RegionID RegionName State     Metro  County  SizeRank    Zhvi
# 0  2017-05-31      6181   New York    NY  New York  Queens         0  672400

# %%
df.loc[df.Date=='2017-05-32'] #어트리뷰트방식, 전체 어트리뷰트를 다 가져온다 .   loc 에서 컴마안하고 인자로하면 열가져옴.
# Out:
# Empty DataFrame
# Columns: [Date, RegionID, RegionName, State, Metro, County, SizeRank, Zhvi]
# Index: []

# %%
#열가져오는 방식 dict 방식과 attribute 방식 .
#열가져올때는 loc,  iloc  
#열하고 행하고 동시에 가져오려면 앞에 , 가 붙었지만 그게없었으면 .

# %%
df.loc[1] #이건행전체 가져옴.
# Out:
# Date                              2017-05-31
# RegionID                               12447
# RegionName                       Los Angeles
# State                                     CA
# Metro         Los Angeles Long Beach-Anaheim
# County                           Los Angeles
# SizeRank                                   1
# Zhvi                                  629900
# Name: 1, dtype: object

# %% [markdown]
# loc,iloc 는 행가져온다 하지만 뒤에 , 하면 열까지 가져온다,

# %% [markdown]
# 열만 가져오고싶을때는 4가지 방식이다 , dict,attrib, loc , iloc 로 열만 가져올 수 있다. 전체 행 다가져오는것 쓸수잇으니까

# %% [markdown]
# ## 행만 가져오고싶을때는 2가지방식이다  loc,iloc ,
# ## 셀만 가져오고싶을때는 4가지 loc,iloc,at,iat

# %% [markdown]
# 조건을 줄 수 있다  . loc 는 기본적으로행만가져오는데  " , " 가 있으면 행하고 열하고 잡아서 슬라이싱이 가능하다 .
# " , "  가 없으면 행만 가져온다 .
# 어떤행을 가져올지는 조건을 줄 수 도 있음.

# %% [markdown]
# 캘리포니아 주에 모든 행을 알고싶다면.

# %%
df.loc[df.State=='CA']  # . 썻으니 그 열중에서 CA 인 값만 가져옴 .  df.State 는 열다 가져옴, attribute 방식.
# Out:
#              Date  RegionID        RegionName State  \
# 1      2017-05-31     12447       Los Angeles    CA
# 6      2017-05-31     54296         San Diego    CA
# 8      2017-05-31     33839          San Jose    CA
# 10     2017-05-31     20330     San Francisco    CA
# 29     2017-05-31     18203            Fresno    CA
# 30     2017-05-31     20288        Sacramento    CA
# 32     2017-05-31     46298        Long Beach    CA
# 38     2017-05-31     13072           Oakland    CA
# 49     2017-05-31     16764           Anaheim    CA
# 50     2017-05-31     47568         Santa Ana    CA
# 55     2017-05-31     47401         Riverside    CA
# 58     2017-05-31      3506       Bakersfield    CA
# 65     2017-05-31      7266          Stockton    CA
# 70     2017-05-31     25934           Modesto    CA
# 83     2017-05-31     20328    San Bernardino    CA
# 84     2017-05-31     24225            Corona    CA
# 85     2017-05-31     51405       Chula Vista    CA
# ...

# %%
df.loc[df['State']=='CA'] # 딕셔너리방식으로 조건줌
# Out:
#              Date  RegionID        RegionName State  \
# 1      2017-05-31     12447       Los Angeles    CA
# 6      2017-05-31     54296         San Diego    CA
# 8      2017-05-31     33839          San Jose    CA
# 10     2017-05-31     20330     San Francisco    CA
# 29     2017-05-31     18203            Fresno    CA
# 30     2017-05-31     20288        Sacramento    CA
# 32     2017-05-31     46298        Long Beach    CA
# 38     2017-05-31     13072           Oakland    CA
# 49     2017-05-31     16764           Anaheim    CA
# 50     2017-05-31     47568         Santa Ana    CA
# 55     2017-05-31     47401         Riverside    CA
# 58     2017-05-31      3506       Bakersfield    CA
# 65     2017-05-31      7266          Stockton    CA
# 70     2017-05-31     25934           Modesto    CA
# 83     2017-05-31     20328    San Bernardino    CA
# 84     2017-05-31     24225            Corona    CA
# 85     2017-05-31     51405       Chula Vista    CA
# ...

# %% [markdown]
# #행만 가져오고싶으면 방식은 ,  몇가지

# %% [markdown]
# 파이썬에서는 iloc 로 모든것을 다 할 수 있다. iloc 쓰기

# %% [markdown]
# filter map reduce  , appl
# pandas 는 EDA  와 전처리하는 방식이니까 정규식과함께쓰인다.

# %% [markdown]
# ##  값을 가져와서 Sorting 하는것.  Sort

# %%
df.sort_values('RegionID',ascending=False)   # axis 가  0 이면 행 ,   1 이면 열을 뜻한다.  ascending 이 기본디폴트, inplace 는 mutable, inplace false 하면 temp 객체 , 실제 기본 값에 반영되지않는다.
# Out:
#              Date  RegionID             RegionName State  \
# 1736   2017-05-31    737791      Town of Mansfield    CT
# 731    2017-05-31    737790               Eastvale    CA
# 10827  2017-05-31    737788        Lebanon Borough    NJ
# 413    2017-05-31    737787         San Tan Valley    AZ
# 9295   2017-05-31    737786          The Sea Ranch    CA
# 8209   2017-05-31    399307       Berwick Township    PA
# 3154   2017-05-31    399305       Swatara Township    PA
# 2813   2017-05-31    399300        Exeter Township    PA
# 741    2017-05-31    399297      Muskegon Township    MI
# 10001  2017-05-31    399293                 Covert    NY
# 2971   2017-05-31    399292      Whitpain Township    PA
# 6119   2017-05-31    399290     Sugarloaf Township    PA
# 6475   2017-05-31    399289          Penn Township    PA
# 2124   2017-05-31    399288     Allendale Township    MI
# 6881   2017-05-31    399287    Portsmouth Township    MI
# ...

# %%
#pandas 는 동시에 여러개 쓰면 리스트다, 
df.sort_values(['RegionID','State'])# 리스트는 순서가있으니까. regionID 로 먼저 sorting 하고 같은게있는경우 두번쨰로 state 로 정렬한다
# Out:
#              Date  RegionID             RegionName State  \
# 3043   2017-05-31      3301               Aberdeen    NC
# 4159   2017-05-31      3304                Absecon    NJ
# 4986   2017-05-31      3305               Accokeek    MD
# 1762   2017-05-31      3310                    Ada    OK
# 3116   2017-05-31      3312            Adairsville    GA
# 10202  2017-05-31      3315                  Adams    TN
# 1136   2017-05-31      3319                Addison    IL
# 10569  2017-05-31      3322                   Addy    WA
# 8018   2017-05-31      3333               Ahwahnee    CA
# 622    2017-05-31      3334                  Aiken    SC
# 3261   2017-05-31      3344                 Albion    MI
# 8315   2017-05-31      3352             Alexandria    AL
# 10456  2017-05-31      3379                   Alta    CA
# 10537  2017-05-31      3403              Andalusia    IL
# 378    2017-05-31      3404               Anderson    SC
# ...

# %%
sorted = df.sort_values(by=['Metro','County','Zhvi'],ascending=[True,True,False])

# %%
sorted.head()
# Out:
#             Date  RegionID    RegionName State     Metro        County  \
# 7108  2017-05-31      6275      Oakville    WA  Aberdeen  Grays Harbor
# 4568  2017-05-31     56078     Montesano    WA  Aberdeen  Grays Harbor
# 4996  2017-05-31     36873          Elma    WA  Aberdeen  Grays Harbor
# 8420  2017-05-31     19269      McCleary    WA  Aberdeen  Grays Harbor
# 9401  2017-05-31     33215  Ocean Shores    WA  Aberdeen  Grays Harbor
#
#       SizeRank    Zhvi
# 7108      7108  186900
# 4568      4568  182000
# 4996      4996  175200
# 8420      8420  170700
# 9401      9401  152400

# %%
df.sort_values('RegionID',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-109-66c6caccfff3> in <module>()
# ----> 1 df.sort_values('RegionID',axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4416             by = by[0]
#    4417             k = self._get_label_or_level_values(by, axis=axis,
# -> 4418                                                 stacklevel=stacklevel)
#    4419
#    4420             if isinstance(ascending, (tuple, list)):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis, stacklevel)
#    1377             values = self.axes[axis].get_level_values(key)._values
#    1378         else:
# -> 1379             raise KeyError(key)
#    1380
#    1381         # Check for duplicates
#
# KeyError: 'RegionID'

# %% [markdown]
# 정렬의 기준이 있어야하는데 ,여기서 서로 다른 행끼리는 비교가 안됨

# %%
#inplace 로 바꿨다가  다시 reset 인덱스하면 (inplace= True ) 로 설정하고 , sort 된결과로 바뀜.

# %%
#reset 인덱스하면 과거의 인덱스가 다시 추가됨.

# %%
#drop index 하면 과거의 인덱스를 없에줌.

# %%
#판다스는 가능하면 안전한게 default 옵션임

# %%
#  reset 인덱스도 많이쓴다 .

# %%
# 데이터 처리에서 가장 중요한거 전처리.
#정규식은 매우중요
#어제는 불러들이는거 오늘하는것은 불러드린것을 수정하는기법들

# %% [markdown]
# --------------------------------------------

# %% [markdown]
# 펑셔널프로그래밍에서 중요한것 MAP, Filter , Reduce 세가지가 있다.

# %%
df.filter

# %%
df.filter(items=['State','Metro']) #like는 특정단어를 포함하는지 안하는지. regex= '^Region',axis=1
# Out:
#       State                           Metro
# 0        NY                        New York
# 1        CA  Los Angeles Long Beach-Anaheim
# 2        IL                         Chicago
# 3        PA                    Philadelphia
# 4        AZ                         Phoenix
# 5        NV                       Las Vegas
# 6        CA                       San Diego
# 7        TX               Dallas-Fort Worth
# 8        CA                        San Jose
# 9        FL                    Jacksonville
# 10       CA                   San Francisco
# 11       TX                          Austin
# 12       MI                         Detroit
# 13       OH                        Columbus
# 14       TN                         Memphis
# 15       NC                       Charlotte
# 16       TX                         El Paso
# 17       MA                          Boston
# 18       WA                         Seattle
# 19       MD                       Baltimore
# ...

# %%
filtered_data= df.filter(regex="Region",axis=1) # 해당 컬럼에 region이라는것이 있는 데이터 . 
filtered_data.head()
# Out:
#    RegionID    RegionName
# 0      6181      New York
# 1     12447   Los Angeles
# 2     17426       Chicago
# 3     13271  Philadelphia
# 4     40326       Phoenix

# %%
filtered_data =  d

# %%
df['Zhvi']>500000
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4        False
# 5        False
# 6         True
# 7        False
# 8         True
# 9        False
# 10        True
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17        True
# 18        True
# 19       False
# 20       False
# 21        True
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 10800    False
# 10801    False
# 10802    False
# 10803    False
# 10804    False
# 10805    False
# 10806    False
# 10807    False
# 10808     True
# 10809    False
# 10810    False
# 10811    False
# 10812    False
# 10813    False
# 10814    False
# 10815    False
# 10816    False
# 10817     True
# 10818     True
# 10819    False
# 10820    False
# 10821    False
# 10822    False
# 10823    False
# 10824    False
# 10825    False
# 10826    False
# ...

# %%
df.loc(df['Zhvi']>500000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-135-08ba8bce121b> in <module>()
# ----> 1 df.loc(df['Zhvi']>500000)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#      96
#      97         if axis is not None:
# ---> 98             axis = self.obj._get_axis_number(axis)
#      99         new_self.axis = axis
#     100         return new_self
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(self, axis)
#     362
#     363     def _get_axis_number(self, axis):
# --> 364         axis = self._AXIS_ALIASES.get(axis, axis)
#     365         if is_integer(axis):
#     366             if axis in self._AXIS_NAMES:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1487     def __hash__(self):
#    1488         raise TypeError('{0!r} objects are mutable, thus they cannot be'
# ...

# %%
df[df.Zhvi>=1000000]
# Out:
#              Date  RegionID              RegionName State  \
# 10     2017-05-31     20330           San Francisco    CA
# 181    2017-05-31     54626               Sunnyvale    CA
# 234    2017-05-31     13713             Santa Clara    CA
# 238    2017-05-31     16992                Berkeley    CA
# 308    2017-05-31     13699               San Mateo    CA
# 360    2017-05-31     26964            Santa Monica    CA
# 423    2017-05-31     13712           Santa Barbara    CA
# 433    2017-05-31     20128            Redwood City    CA
# 479    2017-05-31     32999           Mountain View    CA
# 539    2017-05-31     47164              Pleasanton    CA
# 579    2017-05-31     26374               Palo Alto    CA
# 639    2017-05-31     50749                 Arcadia    CA
# 673    2017-05-31     45565               Greenwich    CT
# 686    2017-05-31     53571           Newport Beach    CA
# 757    2017-05-31      4281               Cupertino    CA
# ...

# %%
filtered_data  = df.filter(like='Met',axis=1) #like는 그 단어를 포함하는것을 가져오게 axis 1 이면 열을 가져와라.

# %%
filtered_data.head()
# Out:
#                             Metro
# 0                        New York
# 1  Los Angeles Long Beach-Anaheim
# 2                         Chicago
# 3                    Philadelphia
# 4                         Phoenix

# %%
#컬럼뽑느것은 dict,attribute,loc,iloc,filter  ( 필터의 경우 컬럼이 많을경우 특정 컬럼가져올경우.)

# %%
#필터는 컬럼 뽑는애다 , axis 값이 들어오면 컬럼뽑는애로 변한ㅏ

# %%
df[(df['Zhvi']>1000000)&(df['State']=='NY')]
# Out:
#              Date  RegionID              RegionName State     Metro  \
# 1132   2017-05-31     18375              Great Neck    NY  New York
# 2405   2017-05-31     54333               Scarsdale    NY  New York
# 2619   2017-05-31     47495                     Rye    NY  New York
# 3032   2017-05-31     25725               Manhasset    NY  New York
# 3064   2017-05-31     18955               Larchmont    NY  New York
# 3474   2017-05-31     18478                Harrison    NY  New York
# 3904   2017-05-31     13937             Southampton    NY  New York
# 4700   2017-05-31     52907                Lawrence    NY  New York
# 5682   2017-05-31     40053             North Hills    NY  New York
# 6386   2017-05-31     53705            Old Westbury    NY  New York
# 6661   2017-05-31     12894              Muttontown    NY  New York
# 6736   2017-05-31     17874              East Hills    NY  New York
# 7728   2017-05-31    194752             Flower Hill    NY  New York
# ...

# %%
filter = df['Metro'].isin(['New York','San Francisco'])    # isin 인 이유는 파이썬 키워드 in 과 혼동할까봐,  
# 뷰티풀수프나, sqlalchemy에서는 _in 을 썻었음 구분을 위해서.

# %%
df[filter].head()
# Out:
#           Date  RegionID     RegionName State          Metro         County  \
# 0   2017-05-31      6181       New York    NY       New York         Queens
# 10  2017-05-31     20330  San Francisco    CA  San Francisco  San Francisco
# 38  2017-05-31     13072        Oakland    CA  San Francisco        Alameda
# 63  2017-05-31     12970         Newark    NJ       New York          Essex
# 72  2017-05-31     25320    Jersey City    NJ       New York         Hudson
#
#     SizeRank     Zhvi
# 0          0   672400
# 10        10  1194300
# 38        38   680100
# 63        63   232800
# 72        72   380000

# %%
df['State'].unique()
# Out:
# array(['NY', 'CA', 'IL', 'PA', 'AZ', 'NV', 'TX', 'FL', 'MI', 'OH', 'TN',
#        'NC', 'MA', 'WA', 'MD', 'CO', 'DC', 'WI', 'OR', 'OK', 'NE', 'NM',
#        'MO', 'VA', 'GA', 'HI', 'MN', 'LA', 'KS', 'AK', 'KY', 'NJ', 'AL',
#        'IN', 'IA', 'ID', 'SC', 'UT', 'AR', 'RI', 'MS', 'CT', 'DE', 'MT',
#        'NH', 'ND', 'WY', 'WV', 'ME'], dtype=object)

# %%
df[df[['State'].isin(['DC','PA'])]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-162-389cf5b153fc> in <module>()
# ----> 1 df[df[['State'].isin(['DC','PA'])]]
#
# AttributeError: 'list' object has no attribute 'isin'

# %%
1 in [1,2,3]
# Out:
# True

# %%
# in 함수는 true 또는 false 돌려줌 .

# %%
df['State'].isin(['DC','PA'])
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21        True
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 10800    False
# 10801    False
# 10802    False
# 10803    False
# 10804    False
# 10805    False
# 10806    False
# 10807    False
# 10808    False
# 10809    False
# 10810    False
# 10811    False
# 10812    False
# 10813    False
# 10814    False
# 10815    False
# 10816    False
# 10817    False
# 10818    False
# 10819    False
# 10820    False
# 10821    False
# 10822    False
# 10823    False
# 10824    False
# 10825    False
# 10826    False
# ...

# %%
df[df['State'].isin(['DC','PA'])]
# Out:
#              Date  RegionID             RegionName State          Metro  \
# 3      2017-05-31     13271           Philadelphia    PA   Philadelphia
# 21     2017-05-31     41568             Washington    DC     Washington
# 54     2017-05-31     26529             Pittsburgh    PA     Pittsburgh
# 230    2017-05-31     16726              Allentown    PA      Allentown
# 301    2017-05-31     11335                   Erie    PA           Erie
# 327    2017-05-31     41629           West Chester    PA   Philadelphia
# 355    2017-05-31    397569     Bethlehem Township    PA      Allentown
# 395    2017-05-31      6696                Reading    PA        Reading
# 470    2017-05-31     20398               Scranton    PA       Scranton
# 478    2017-05-31     17008              Bethlehem    PA      Allentown
# 604    2017-05-31    397184          York Township    PA           York
# 664    2017-05-31    398816              Lancaster    PA      Lancaster
# ...

# %% [markdown]
# ------------

# %%
df[True] # 조건이 들어가야함.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-169-570d3e379dbf> in <module>()
# ----> 1 df[True]
#
# ...

# %%
filter = df.isin({'State':['CA'],'Metro':['San Francisco']}) #in 다음에 dict 가 오면  key 만 체크함.

# %%
filter
# Out:
#         Date  RegionID  RegionName  State  Metro  County  SizeRank   Zhvi
# 0      False     False       False  False  False   False     False  False
# 1      False     False       False   True  False   False     False  False
# 2      False     False       False  False  False   False     False  False
# 3      False     False       False  False  False   False     False  False
# 4      False     False       False  False  False   False     False  False
# 5      False     False       False  False  False   False     False  False
# 6      False     False       False   True  False   False     False  False
# 7      False     False       False  False  False   False     False  False
# 8      False     False       False   True  False   False     False  False
# 9      False     False       False  False  False   False     False  False
# 10     False     False       False   True   True   False     False  False
# 11     False     False       False  False  False   False     False  False
# ...

# %%
df[filter] # Nan 은 값이 없는것 .
# Out:
#       Date  RegionID RegionName State          Metro County  SizeRank  Zhvi
# 0      NaN       NaN        NaN   NaN            NaN    NaN       NaN   NaN
# 1      NaN       NaN        NaN    CA            NaN    NaN       NaN   NaN
# 2      NaN       NaN        NaN   NaN            NaN    NaN       NaN   NaN
# 3      NaN       NaN        NaN   NaN            NaN    NaN       NaN   NaN
# 4      NaN       NaN        NaN   NaN            NaN    NaN       NaN   NaN
# 5      NaN       NaN        NaN   NaN            NaN    NaN       NaN   NaN
# 6      NaN       NaN        NaN    CA            NaN    NaN       NaN   NaN
# 7      NaN       NaN        NaN   NaN            NaN    NaN       NaN   NaN
# 8      NaN       NaN        NaN    CA            NaN    NaN       NaN   NaN
# 9      NaN       NaN        NaN   NaN            NaN    NaN       NaN   NaN
# 10     NaN       NaN        NaN    CA  San Francisco    NaN       NaN   NaN
# ...

# %%
df['State'].isin(['DC','PA']) #시리즈가 데이터에 조건으로 들어가면  , 행을뽑는다.
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21        True
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 10800    False
# 10801    False
# 10802    False
# 10803    False
# 10804    False
# 10805    False
# 10806    False
# 10807    False
# 10808    False
# 10809    False
# 10810    False
# 10811    False
# 10812    False
# 10813    False
# 10814    False
# 10815    False
# 10816    False
# 10817    False
# 10818    False
# 10819    False
# 10820    False
# 10821    False
# 10822    False
# 10823    False
# 10824    False
# 10825    False
# 10826    False
# ...

# %%
df[df['State'].isin(['DC','PA'])] #위의 조건을 넣으면 ,  True 인것들만 출력한다.
# Out:
#              Date  RegionID             RegionName State          Metro  \
# 3      2017-05-31     13271           Philadelphia    PA   Philadelphia
# 21     2017-05-31     41568             Washington    DC     Washington
# 54     2017-05-31     26529             Pittsburgh    PA     Pittsburgh
# 230    2017-05-31     16726              Allentown    PA      Allentown
# 301    2017-05-31     11335                   Erie    PA           Erie
# 327    2017-05-31     41629           West Chester    PA   Philadelphia
# 355    2017-05-31    397569     Bethlehem Township    PA      Allentown
# 395    2017-05-31      6696                Reading    PA        Reading
# 470    2017-05-31     20398               Scranton    PA       Scranton
# 478    2017-05-31     17008              Bethlehem    PA      Allentown
# 604    2017-05-31    397184          York Township    PA           York
# 664    2017-05-31    398816              Lancaster    PA      Lancaster
# ...

# %%
df.isin({'State':['CA'],'Metro':["San Francisco"]}) #df 는 시리즈가아니니까 , 여러개의 조건을 넣을 수있따. 이때는 dict 사용하여  조건을 줌.
        #데이터 프레임에 조건을 주었기때문에 데이터 프레임으로 나옴. 
    #컬럼이 한개면 시리즈 , 컬럼이 여러개면 프레임.
# Out:
#         Date  RegionID  RegionName  State  Metro  County  SizeRank   Zhvi
# 0      False     False       False  False  False   False     False  False
# 1      False     False       False   True  False   False     False  False
# 2      False     False       False  False  False   False     False  False
# 3      False     False       False  False  False   False     False  False
# 4      False     False       False  False  False   False     False  False
# 5      False     False       False  False  False   False     False  False
# 6      False     False       False   True  False   False     False  False
# 7      False     False       False  False  False   False     False  False
# 8      False     False       False   True  False   False     False  False
# 9      False     False       False  False  False   False     False  False
# 10     False     False       False   True   True   False     False  False
# 11     False     False       False  False  False   False     False  False
# ...

# %%
df['Date']
# Out:
# 0        2017-05-31
# 1        2017-05-31
# 2        2017-05-31
# 3        2017-05-31
# 4        2017-05-31
# 5        2017-05-31
# 6        2017-05-31
# 7        2017-05-31
# 8        2017-05-31
# 9        2017-05-31
# 10       2017-05-31
# 11       2017-05-31
# 12       2017-05-31
# 13       2017-05-31
# 14       2017-05-31
# 15       2017-05-31
# 16       2017-05-31
# 17       2017-05-31
# 18       2017-05-31
# 19       2017-05-31
# 20       2017-05-31
# 21       2017-05-31
# 22       2017-05-31
# 23       2017-05-31
# 24       2017-05-31
# 25       2017-05-31
# 26       2017-05-31
# 27       2017-05-31
# 28       2017-05-31
# 29       2017-05-31
#             ...
# 10800    2017-05-31
# 10801    2017-05-31
# 10802    2017-05-31
# 10803    2017-05-31
# 10804    2017-05-31
# 10805    2017-05-31
# 10806    2017-05-31
# 10807    2017-05-31
# 10808    2017-05-31
# 10809    2017-05-31
# 10810    2017-05-31
# 10811    2017-05-31
# 10812    2017-05-31
# 10813    2017-05-31
# ...

# %%
df[['Date']]
# Out:
#              Date
# 0      2017-05-31
# 1      2017-05-31
# 2      2017-05-31
# 3      2017-05-31
# 4      2017-05-31
# 5      2017-05-31
# 6      2017-05-31
# 7      2017-05-31
# 8      2017-05-31
# 9      2017-05-31
# 10     2017-05-31
# 11     2017-05-31
# 12     2017-05-31
# 13     2017-05-31
# 14     2017-05-31
# 15     2017-05-31
# 16     2017-05-31
# 17     2017-05-31
# 18     2017-05-31
# 19     2017-05-31
# 20     2017-05-31
# 21     2017-05-31
# 22     2017-05-31
# 23     2017-05-31
# 24     2017-05-31
# 25     2017-05-31
# 26     2017-05-31
# 27     2017-05-31
# 28     2017-05-31
# 29     2017-05-31
# ...           ...
# 10800  2017-05-31
# 10801  2017-05-31
# 10802  2017-05-31
# 10803  2017-05-31
# 10804  2017-05-31
# 10805  2017-05-31
# 10806  2017-05-31
# 10807  2017-05-31
# 10808  2017-05-31
# 10809  2017-05-31
# 10810  2017-05-31
# 10811  2017-05-31
# 10812  2017-05-31
# 10813  2017-05-31
# 10814  2017-05-31
# 10815  2017-05-31
# 10816  2017-05-31
# 10817  2017-05-31
# ...

# %%
df.loc[1:3] # 데이터프레임
# Out:
#          Date  RegionID    RegionName State                           Metro  \
# 1  2017-05-31     12447   Los Angeles    CA  Los Angeles Long Beach-Anaheim
# 2  2017-05-31     17426       Chicago    IL                         Chicago
# 3  2017-05-31     13271  Philadelphia    PA                    Philadelphia
#
#          County  SizeRank    Zhvi
# 1   Los Angeles         1  629900
# 2          Cook         2  222700
# 3  Philadelphia         3  137300

# %%
df.loc[1:3,"Date"] #시리즈 .
# Out:
# 1    2017-05-31
# 2    2017-05-31
# 3    2017-05-31
# Name: Date, dtype: object

# %%
df.loc[1:3,["Date"]]
# Out:
#          Date
# 1  2017-05-31
# 2  2017-05-31
# 3  2017-05-31

# %%
#다시 데이터프레임. 리스트로 넣었으니까.

# %%
#이게 왜중요하냐면 시리즈에서 메소드와 데이터프레임에서 사용할수있는 메소드가 다르기때문에, 저런 테크닉써야함. 
#따라서 loc,iloc 는 데이터프레임 또는 시리즈를 리턴할 수 있다.

# %%
#df[조건] 조건중의 참인 것만 보여줌

# %%
df[df.isin({'State':['CA'],'Metro':["San Francisco"]})] #df 는 시리즈가아니니까 , 여러개의 조건을 넣을 수있따. 이때는 dict 사용하여  조건을 줌.
        #데이터 프레임에 조건을 주었기때문에 데이터 프레임으로 나옴. 
    #컬럼이 한개면 시리즈 , 컬럼이 여러개면 프레임.
# Out:
#       Date  RegionID RegionName State          Metro County  SizeRank  Zhvi
# 0      NaN       NaN        NaN   NaN            NaN    NaN       NaN   NaN
# 1      NaN       NaN        NaN    CA            NaN    NaN       NaN   NaN
# 2      NaN       NaN        NaN   NaN            NaN    NaN       NaN   NaN
# 3      NaN       NaN        NaN   NaN            NaN    NaN       NaN   NaN
# 4      NaN       NaN        NaN   NaN            NaN    NaN       NaN   NaN
# 5      NaN       NaN        NaN   NaN            NaN    NaN       NaN   NaN
# 6      NaN       NaN        NaN    CA            NaN    NaN       NaN   NaN
# 7      NaN       NaN        NaN   NaN            NaN    NaN       NaN   NaN
# 8      NaN       NaN        NaN    CA            NaN    NaN       NaN   NaN
# 9      NaN       NaN        NaN   NaN            NaN    NaN       NaN   NaN
# 10     NaN       NaN        NaN    CA  San Francisco    NaN       NaN   NaN
# ...

# %%
#true 면 보여주는거고 false 면 안보여주는건데 결과물이 이상하다 .

# %%
#이것은 나중에 알려주겠다.
#지금은 dataframe 이랑 series 구별하는것

# %%
df.axes  # axes 는 row 와 column  정보를 다보여준다 .
# Out:
# [RangeIndex(start=0, stop=10830, step=1),
#  Index(['Date', 'RegionID', 'RegionName', 'State', 'Metro', 'County',
#         'SizeRank', 'Zhvi'],
#        dtype='object')]

# %%
len(df.axes)
# Out:
# 2

# %% [markdown]
# 보통 두개면, 앞에것이 row , 뒤의것이 column.
# 앞에것은 rangeIndex , 뒤는 컬럼.

# %%
df.columns
# Out:
# Index(['Date', 'RegionID', 'RegionName', 'State', 'Metro', 'County',
#        'SizeRank', 'Zhvi'],
#       dtype='object')

# %% [markdown]
# 컬럼만 볼때 .

# %%
df.axes[1] # 이거와 같다
# Out:
# Index(['Date', 'RegionID', 'RegionName', 'State', 'Metro', 'County',
#        'SizeRank', 'Zhvi'],
#       dtype='object')

# %%
# qgrid 라는것으로 필터링 할 수 도 있다.  https://github.com/quantopian/qgrid

# %%
#데이터 프레임은 : 시리즈의 집합  + 인덱스 , 엑시스는 전부다 인덱스로 구성됨.

# %%
df.head()
# Out:
#          Date  RegionID    RegionName State                           Metro  \
# 0  2017-05-31      6181      New York    NY                        New York
# 1  2017-05-31     12447   Los Angeles    CA  Los Angeles Long Beach-Anaheim
# 2  2017-05-31     17426       Chicago    IL                         Chicago
# 3  2017-05-31     13271  Philadelphia    PA                    Philadelphia
# 4  2017-05-31     40326       Phoenix    AZ                         Phoenix
#
#          County  SizeRank    Zhvi
# 0        Queens         0  672400
# 1   Los Angeles         1  629900
# 2          Cook         2  222700
# 3  Philadelphia         3  137300
# 4      Maricopa         4  211300

# %% [markdown]
# ## axis = 0    ROW

# %%
df.mean(axis=0) # axis  = 0 은 행 , 컬럼이 숫자 값일때만 평균이 나온다 .
# Out:
# RegionID     84344.818837
# SizeRank      5414.500000
# Zhvi        250307.590028
# dtype: float64

# %% [markdown]
# ## axis  =1   COILUMNS

# %%
df.mean(axis=1) # 평균이 전체 행만큼 갯수.
# Out:
# 0        2.261937e+05
# 1        2.141160e+05
# 2        8.004267e+04
# 3        5.019133e+04
# 4        8.387667e+04
# 5        7.848800e+04
# 6        2.088007e+05
# 7        6.761167e+04
# 8        3.037490e+05
# 9        5.919967e+04
# 10       4.048800e+05
# 11       1.106107e+05
# 12       1.975800e+04
# 13       4.641100e+04
# 14       3.797500e+04
# 15       6.928600e+04
# 16       4.378300e+04
# 17       1.996287e+05
# 18       2.287850e+05
# 19       4.154733e+04
# 20       1.314377e+05
# 21       1.991630e+05
# 22       7.821333e+04
# 23       3.796633e+04
# 24       5.743500e+04
# 25       1.437660e+05
# 26       5.531700e+04
# 27       6.409300e+04
# 28       7.101900e+04
# 29       7.697733e+04
#              ...
# 10800    9.508133e+04
# 10801    4.300067e+04
# 10802    1.580057e+05
# 10803    1.068157e+05
# 10804    1.228323e+05
# 10805    6.629900e+04
# 10806    1.105600e+05
# 10807    4.130633e+04
# 10808    3.759180e+05
# 10809    3.538200e+04
# ...

# %%
df.RegionID.max()    # 얘는 axis 0 , axis 1 필요하지않다 . axis 는 2차원에서만 필요함  즉 2차원 데이터프레임에서 들어감. 
#df["RegionID"]같은 시리즈는 1차원임
# Out:
# 737791

# %%
df.mean(axis='rows')
# Out:
# RegionID     84344.818837
# SizeRank      5414.500000
# Zhvi        250307.590028
# dtype: float64

# %%
df.mean(axis='columns').head() #이것도 가능
# Out:
# 0    226193.666667
# 1    214116.000000
# 2     80042.666667
# 3     50191.333333
# 4     83876.666667
# dtype: float64

# %%
df.filter(regex = "Region",axis = 1)  #
# Out:
#        RegionID         RegionName
# 0          6181           New York
# 1         12447        Los Angeles
# 2         17426            Chicago
# 3         13271       Philadelphia
# 4         40326            Phoenix
# 5         18959          Las Vegas
# 6         54296          San Diego
# 7         38128             Dallas
# 8         33839           San Jose
# 9         25290       Jacksonville
# 10        20330      San Francisco
# 11        10221             Austin
# 12        17762            Detroit
# 13        10920           Columbus
# 14        32811            Memphis
# 15        24043          Charlotte
# 16        17933            El Paso
# 17        44269             Boston
# 18        16037            Seattle
# 19         3523          Baltimore
# 20        11093             Denver
# 21        41568         Washington
# 22         6118          Nashville
# 23         5976          Milwaukee
# 24         7481             Tucson
# 25        13373           Portland
# ...

# %%
df.filter(regex='([0-9])',axis=0)   #인덱스가 숫자로 되어있다
# Out:
#              Date  RegionID         RegionName State  \
# 0      2017-05-31      6181           New York    NY
# 1      2017-05-31     12447        Los Angeles    CA
# 2      2017-05-31     17426            Chicago    IL
# 3      2017-05-31     13271       Philadelphia    PA
# 4      2017-05-31     40326            Phoenix    AZ
# 5      2017-05-31     18959          Las Vegas    NV
# 6      2017-05-31     54296          San Diego    CA
# 7      2017-05-31     38128             Dallas    TX
# 8      2017-05-31     33839           San Jose    CA
# 9      2017-05-31     25290       Jacksonville    FL
# 10     2017-05-31     20330      San Francisco    CA
# 11     2017-05-31     10221             Austin    TX
# 12     2017-05-31     17762            Detroit    MI
# 13     2017-05-31     10920           Columbus    OH
# 14     2017-05-31     32811            Memphis    TN
# 15     2017-05-31     24043          Charlotte    NC
# 16     2017-05-31     17933            El Paso    TX
# ...

# %%
netflix =   pd.read_csv('data-netflix.csv',index_col='title') # 타이틀이 인덱스가됨.

# %%
netflix
# Out:
#                                            rating  \
# title
# White Chicks                                PG-13
# Lucky Number Slevin                             R
# Grey's Anatomy                              TV-14
# Prison Break                                TV-14
# How I Met Your Mother                       TV-PG
# Supernatural                                TV-14
# Breaking Bad                                TV-MA
# The Vampire Diaries                         TV-14
# The Walking Dead                            TV-MA
# Pretty Little Liars                         TV-14
# Once Upon a Time                            TV-PG
# Sherlock                                    TV-14
# Death Note                                  TV-14
# Naruto                                      TV-PG
# The Hunter                                      R
# Lottie Dottie Chicken                        TV-Y
# Arrow                                       TV-14
# Black Mirror                                TV-MA
# ...

# %%
netflix.filter(regex='Anato',axis=0)
# Out:
#                rating                                        ratingLevel  \
# title
# Grey's Anatomy  TV-14  Parents strongly cautioned. May be unsuitable ...
# Grey's Anatomy  TV-14  Parents strongly cautioned. May be unsuitable ...
# Grey's Anatomy  TV-14  Parents strongly cautioned. May be unsuitable ...
# Grey's Anatomy  TV-14  Parents strongly cautioned. May be unsuitable ...
# Grey's Anatomy  TV-14  Parents strongly cautioned. May be unsuitable ...
# Grey's Anatomy  TV-14  Parents strongly cautioned. May be unsuitable ...
#
#                 ratingDescription  release year  user rating score  \
# title
# Grey's Anatomy                 90          2016               98.0
# Grey's Anatomy                 90          2016               98.0
# Grey's Anatomy                 90          2016               98.0
# Grey's Anatomy                 90          2016               98.0
# Grey's Anatomy                 90          2016               98.0
# ...

# %%
#이럴때 정규식을 쓴다.

# %%
data  = pd.read_csv('data-zillow.csv')

# %%
data.head()
# Out:
#          Date  RegionID    RegionName State                           Metro  \
# 0  2017-05-31      6181      New York    NY                        New York
# 1  2017-05-31     12447   Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 2  2017-05-31     17426       Chicago    IL                         Chicago
# 3  2017-05-31     13271  Philadelphia    PA                    Philadelphia
# 4  2017-05-31     40326       Phoenix    AZ                         Phoenix
#
#          County  SizeRank    Zhvi
# 0        Queens         0  672400
# 1   Los Angeles         1  629900
# 2          Cook         2  222700
# 3  Philadelphia         3  137300
# 4      Maricopa         4  211300

# %%
# sqlite 
# ORM 웹시스템도 만들고 , 분석할때 쓸수있다. sql 모르는사람은 orm 쓰니까
# 몽고db 도 판다스에서 불러올 수 있다.

#정규식 쓸거지만 쉬운방법도 써보자 .

# %% [markdown]
# ## Check for a Substring

# %%
data.info() #pandas 에서 object 라고 나온것은 대부분문자열이다 예외: 시간관련된것
#문자열은 regrex 로 해결함.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10830 entries, 0 to 10829
# Data columns (total 8 columns):
# Date          10830 non-null object
# RegionID      10830 non-null int64
# RegionName    10830 non-null object
# State         10830 non-null object
# Metro         10256 non-null object
# County        10830 non-null object
# SizeRank      10830 non-null int64
# Zhvi          10830 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 677.0+ KB

# %%
data.RegionName.str.capitalize  # data.RegionName 은 attr 방식으로 뽑아낸 시리즈 .  obj 경우 .str 을쓰면.  str 배웠을떄 쓸수있는 .str 하면 문자열에관한 help function을 지원해줌.
# Out:
# <bound method _noarg_wrapper.<locals>.wrapper of <pandas.core.strings.StringMethods object at 0x000001C8D88D44A8>>

# %%
data['RegionName'].str  # 이렇게해도 되는데  , 자동완성이 안됨. 주피터 노트북의 버그랑 비슷함. 자동완성인데안나옴.  따라서 attribute 방식을 많이씀 자동완성으로 나와서.

# %%
#bound method 는 () 이거 써야한다.

# %%
data.RegionName.str.capitalize()
# Out:
# 0                 New york
# 1              Los angeles
# 2                  Chicago
# 3             Philadelphia
# 4                  Phoenix
# 5                Las vegas
# 6                San diego
# 7                   Dallas
# 8                 San jose
# 9             Jacksonville
# 10           San francisco
# 11                  Austin
# 12                 Detroit
# 13                Columbus
# 14                 Memphis
# 15               Charlotte
# 16                 El paso
# 17                  Boston
# 18                 Seattle
# 19               Baltimore
# 20                  Denver
# 21              Washington
# 22               Nashville
# 23               Milwaukee
# 24                  Tucson
# 25                Portland
# 26           Oklahoma city
# 27                   Omaha
# 28             Albuquerque
# 29                  Fresno
#                ...
# 10800         Mount sidney
# 10801          Cedar grove
# 10802                Clark
# ...

# %%
data["RegionName"].str.upper() # 자동완성 안되는거지만 똑같다.
# Out:
# 0                 NEW YORK
# 1              LOS ANGELES
# 2                  CHICAGO
# 3             PHILADELPHIA
# 4                  PHOENIX
# 5                LAS VEGAS
# 6                SAN DIEGO
# 7                   DALLAS
# 8                 SAN JOSE
# 9             JACKSONVILLE
# 10           SAN FRANCISCO
# 11                  AUSTIN
# 12                 DETROIT
# 13                COLUMBUS
# 14                 MEMPHIS
# 15               CHARLOTTE
# 16                 EL PASO
# 17                  BOSTON
# 18                 SEATTLE
# 19               BALTIMORE
# 20                  DENVER
# 21              WASHINGTON
# 22               NASHVILLE
# 23               MILWAUKEE
# 24                  TUCSON
# 25                PORTLAND
# 26           OKLAHOMA CITY
# 27                   OMAHA
# 28             ALBUQUERQUE
# 29                  FRESNO
#                ...
# 10800         MOUNT SIDNEY
# 10801          CEDAR GROVE
# 10802                CLARK
# ...

# %%
#attr 방식은 단점이  컬럼명에 공백이있을때 안된다 .

# %%
data["RegionName"] =  data["RegionName"].str.upper()

# %%
data.head() #대문자로 바뀐것을 확인한다
# Out:
#          Date  RegionID    RegionName State                           Metro  \
# 0  2017-05-31      6181      NEW YORK    NY                        New York
# 1  2017-05-31     12447   LOS ANGELES    CA  Los Angeles-Long Beach-Anaheim
# 2  2017-05-31     17426       CHICAGO    IL                         Chicago
# 3  2017-05-31     13271  PHILADELPHIA    PA                    Philadelphia
# 4  2017-05-31     40326       PHOENIX    AZ                         Phoenix
#
#          County  SizeRank    Zhvi
# 0        Queens         0  672400
# 1   Los Angeles         1  629900
# 2          Cook         2  222700
# 3  Philadelphia         3  137300
# 4      Maricopa         4  211300

# %%
data.RegionName.str.replace("YORK","york!") #object 형일때 문자형에 관한거 쓰려면 .str  을쓴다. 여기도 인자에 regex 가 나온다!!!
# Out:
# 0                NEW york!
# 1              LOS ANGELES
# 2                  CHICAGO
# 3             PHILADELPHIA
# 4                  PHOENIX
# 5                LAS VEGAS
# 6                SAN DIEGO
# 7                   DALLAS
# 8                 SAN JOSE
# 9             JACKSONVILLE
# 10           SAN FRANCISCO
# 11                  AUSTIN
# 12                 DETROIT
# 13                COLUMBUS
# 14                 MEMPHIS
# 15               CHARLOTTE
# 16                 EL PASO
# 17                  BOSTON
# 18                 SEATTLE
# 19               BALTIMORE
# 20                  DENVER
# 21              WASHINGTON
# 22               NASHVILLE
# 23               MILWAUKEE
# 24                  TUCSON
# 25                PORTLAND
# 26           OKLAHOMA CITY
# 27                   OMAHA
# 28             ALBUQUERQUE
# 29                  FRESNO
#                ...
# 10800         MOUNT SIDNEY
# 10801          CEDAR GROVE
# 10802                CLARK
# ...

# %%
data.RegionName.str #str 함수들을 대부분다 가져온 것이다 차이점은 :  함수형 기법으로 만들어져있다. 컬럼을 돌아다니면서 모두 바꿔주니까 . 
#함수형기법에서 가장 많이 쓰이는것 , map,filter,reduce.

# %%
data.RegionName.map(lambda x : x +'정유미')
# Out:
# 0                 NEW YORK정유미
# 1              LOS ANGELES정유미
# 2                  CHICAGO정유미
# 3             PHILADELPHIA정유미
# 4                  PHOENIX정유미
# 5                LAS VEGAS정유미
# 6                SAN DIEGO정유미
# 7                   DALLAS정유미
# 8                 SAN JOSE정유미
# 9             JACKSONVILLE정유미
# 10           SAN FRANCISCO정유미
# 11                  AUSTIN정유미
# 12                 DETROIT정유미
# 13                COLUMBUS정유미
# 14                 MEMPHIS정유미
# 15               CHARLOTTE정유미
# 16                 EL PASO정유미
# 17                  BOSTON정유미
# 18                 SEATTLE정유미
# 19               BALTIMORE정유미
# 20                  DENVER정유미
# 21              WASHINGTON정유미
# 22               NASHVILLE정유미
# 23               MILWAUKEE정유미
# 24                  TUCSON정유미
# 25                PORTLAND정유미
# 26           OKLAHOMA CITY정유미
# 27                   OMAHA정유미
# 28             ALBUQUERQUE정유미
# 29                  FRESNO정유미
#                  ...
# ...

# %%
data.RegionID.map(lambda x:x.format(".4d")) #함수형 기법인 map 은 들어오는것을 하나씩 바꿔준다 . 컬럼에 있는 값 하나씩  다 바꿔줌.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-270-ffc669c2efb3> in <module>()
# ----> 1 data.RegionID.map(lambda x:x.format(".4d"))
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    2994         """
#    2995         new_values = super(Series, self)._map_values(
# -> 2996             arg, na_action=na_action)
#    2997         return self._constructor(new_values,
#    2998                                  index=self.index).__finalize__(self)
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#    1002
#    1003         # mapper is a function
# -> 1004         new_values = map_f(values, mapper)
#    1005
#    1006         return new_values
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-270-ffc669c2efb3> in <lambda>(x)
# ...

# %%
data['새로운컬럼'] = data.County.str.len()

# %%
data.head()
# Out:
#          Date  RegionID    RegionName State                           Metro  \
# 0  2017-05-31      6181      NEW YORK    NY                        New York
# 1  2017-05-31     12447   LOS ANGELES    CA  Los Angeles-Long Beach-Anaheim
# 2  2017-05-31     17426       CHICAGO    IL                         Chicago
# 3  2017-05-31     13271  PHILADELPHIA    PA                    Philadelphia
# 4  2017-05-31     40326       PHOENIX    AZ                         Phoenix
#
#          County  SizeRank    Zhvi  새로운컬럼
# 0        Queens         0  672400      6
# 1   Los Angeles         1  629900     11
# 2          Cook         2  222700      4
# 3  Philadelphia         3  137300     12
# 4      Maricopa         4  211300      8

# %%
# 내가 필요한 데이터가 없을 확률이 많다.

# %%
data.RegionName.str.replace('','') #공백을 없에줌
# Out:
# 0                 NEW YORK
# 1              LOS ANGELES
# 2                  CHICAGO
# 3             PHILADELPHIA
# 4                  PHOENIX
# 5                LAS VEGAS
# 6                SAN DIEGO
# 7                   DALLAS
# 8                 SAN JOSE
# 9             JACKSONVILLE
# 10           SAN FRANCISCO
# 11                  AUSTIN
# 12                 DETROIT
# 13                COLUMBUS
# 14                 MEMPHIS
# 15               CHARLOTTE
# 16                 EL PASO
# 17                  BOSTON
# 18                 SEATTLE
# 19               BALTIMORE
# 20                  DENVER
# 21              WASHINGTON
# 22               NASHVILLE
# 23               MILWAUKEE
# 24                  TUCSON
# 25                PORTLAND
# 26           OKLAHOMA CITY
# 27                   OMAHA
# 28             ALBUQUERQUE
# 29                  FRESNO
#                ...
# 10800         MOUNT SIDNEY
# 10801          CEDAR GROVE
# 10802                CLARK
# ...
